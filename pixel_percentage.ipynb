# %%
import pandas as pd
import numpy as np
import cv2
import glob 
import matplotlib.pylab as plt

# %%
class DetectPixels:
    def __init__(self, filename):
      self.filename = filename
        
        
    def print_image(filename):
        image = cv2.imread(filename)
        print(f"shape of the image: {(image.shape)}") # hight, width, channel" 
        fig, ax = plt.subplots(figsize=(10,10))# showing an image
        ax.imshow(image)
        return image
    
    def to_grayscale(filename):
        # Use the cvtColor() function to grayscale the image 
        gray_image=cv2.imread(filename,0)
        window_name='Grayscale Conversion OpenCV'
        cv2.namedWindow(window_name, cv2.WINDOW_NORMAL)
        cv2.imshow(window_name,gray_image)
        cv2.waitKey(0)
        cv2.destroyAllWindows()
      
    def calculate_pixel_density(image):
        # Flatten the image and create a pandas Series
        pixel_dist = pd.Series(image.flatten(), name='pixel')
        # Create a DataFrame with the 'index' column
        df = pd.DataFrame(pixel_dist)
        zero_count = df.loc[(df['pixel'] != 255)]
        print(f"Black colour pixel percentage: {len(zero_count)/len(df)}")

# %%
filename = "Free_Test_Data_1MB_PDF.jpg"
white_image = DetectPixels.print_image(filename)
DetectPixels.calculate_pixel_density(white_image)
DetectPixels.to_grayscale(white_image)
# Out:
# shape of the image: (1650, 1275, 3)
# Black colour pixel percentage: 0.0
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %%
filename = "non-text-searchable.jpg"
paragraph_image = DetectPixels.print_image(filename)
DetectPixels.calculate_pixel_density(paragraph_image)
DetectPixels.to_grayscale(paragraph_image)
# Out:
# shape of the image: (1650, 1275, 3)
# Black colour pixel percentage: 0.03513123390770449
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %%
filename = "letters.jpg"
few_paragraphs_image = DetectPixels.print_image(filename)
DetectPixels.calculate_pixel_density(few_paragraphs_image)
# Out:
# shape of the image: (1650, 1275, 3)
# Black colour pixel percentage: 0.00830992275698158

# %%
filename = "picture.jpg"
picture_image = DetectPixels.print_image(filename)
DetectPixels.calculate_pixel_density(picture_image)
# Out:
# shape of the image: (1650, 1275, 3)
# Black colour pixel percentage: 0.00830992275698158
